# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
import pickle
import requests
from collections import deque
from bs4 import BeautifulSoup

# %%
print(os.getcwd())
path = "/content/gdrive/MyDrive/CS-582_project"
os.chdir(path)

# %%
# number of pages to crawl
page_crawl_limit = 6000

# %%
# to make sure error log file is initially empty
error_file = "error_log.txt"
f = open(error_file, "w+")
f.close()

# %% [markdown]
# **Domain for the crawler**

# %%
domain = "uic.edu"

# starting url
init_url = "https://cs.uic.edu"

# folder to store retrieved web pages
pages_directory_path = "./RetrievedPages/"

ignored_exten = [
    ".xlsx",
    ".css",
    ".js",
    ".aspx",
    ".png",
    ".jpg",
    ".jpeg",
    ".gif",
    ".svg",
    ".ico",
    ".mp4",
    ".avi",
    ".tar",
    ".gz",
    ".tgz",
    ".zip",
    ".pdf",
    ".doc",
    ".docx",
    ".ppt",
    ".pptx",
    ".xls"]

# %%
#  Breadth First Search web traversal for URL'S
url_queue = deque()
url_queue.append(init_url)

# storing traversed URLs
crawled_urls = []
crawled_urls.append(init_url)

# dict to track pages fetched and stored in folder
crawled_pages = {}
page_num = 1

url_queue
# Out:
# deque(['https://cs.uic.edu'])

# %%
while url_queue:
  try:
    # fetch the first url from the queue
    url = url_queue.popleft()
    # HTML code
    request = requests.get(url)
    # print(request)

    if request.status_code == 200:

      parser = BeautifulSoup(request.text, "lxml")
      # anchor tags
      extracted_tags = parser.find_all("a")
      # print(extracted_tags)

      # print("*********************")

      if len(extracted_tags) != 0:
        crawled_pages[page_num] = url
        file_name = pages_directory_path + str(page_num)

        # create a directory if RetrievedPages directory doesn't exist,
        # if exists no changes made to the directory
        os.makedirs(os.path.dirname(file_name), exist_ok=True)

        # save the retrievd web page from the current url
        with open(file_name, "w", encoding="utf-8") as f:
            f.write(request.text)
        f.close()

        for tags in extracted_tags:
          ref_url = tags.get("href")
  

          if (ref_url is not None and ref_url.startswith("http")):
            if (not any (i in ref_url for i in ignored_exten)):
              ref_url = ref_url.lower()
              ref_url = ref_url.split('#')[0]
              ref_url = ref_url.split('?', maxsplit=1)[0]
              ref_url = ref_url.rstrip('/')
              ref_url = ref_url.strip()

            if ref_url not in crawled_urls and domain in ref_url:
              url_queue.append(ref_url)                 
              crawled_urls.append(ref_url)
            
        if (len(crawled_pages) > page_crawl_limit):
          break     
        page_num += 1        

  except Exception as e:
      with open(error_file, "a+") as f:
                  # add error message to error log
        f.write(f"Unable to connect to {url}")
        f.write(f"\nError occured: {e}\n\n")
      f.close()

      print("Unable to connect to ", url)
      print("Error occured: ", e, " \n")
      continue
# Out:
# Unable to connect to  https://give.engineering.uic.edu
# Error occured:  HTTPSConnectionPool(host='give.engineering.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://emergency.uic.edu
# Error occured:  HTTPSConnectionPool(host='emergency.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://outlook.uic.edu
# Error occured:  HTTPSConnectionPool(host='outlook.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://emergency.uic.edu
# Error occured:  HTTPSConnectionPool(host='emergency.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://give.uic.edu
# Error occured:  HTTPSConnectionPool(host='give.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://gat.uic.edu
# Error occured:  HTTPSConnectionPool(host='gat.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://tag.uic.edu
# Error occured:  HTTPSConnectionPool(host='tag.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://news.uic.edu/social-media-directory
# Error occured:  HTTPSConnectionPool(host='news.uic.edu', port=443): Max retries exceeded with url: /social-media-directory (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://fmweb.fm.uic.edu/Trans/paratransit.aspx
# Error occured:  HTTPConnectionPool(host='fmweb.fm.uic.edu', port=80): Max retries exceeded with url: /Trans/paratransit.aspx (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f5aa3988a90>: Failed to establish a new connection: [Errno -2] Name or service not known'))
#
# Unable to connect to  https://pharmacy.uic.edu
# Error occured:  HTTPSConnectionPool(host='pharmacy.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://vcsaonline.uic.edu/lms
# Error occured:  HTTPSConnectionPool(host='vcsaonline.uic.edu', port=443): Max retries exceeded with url: /lms (Caused by SSLError(SSLCertVerificationError("hostname 'vcsaonline.uic.edu' doesn't match 'dev.sa.uic.edu'")))
#
# Unable to connect to  https://events.uic.edu
# Error occured:  HTTPSConnectionPool(host='events.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1091)')))
#
# Unable to connect to  https://password.uic.edu
# Error occured:  HTTPSConnectionPool(host='password.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://news.uic.edu/uicnews/section/circleinterchange
# Error occured:  HTTPSConnectionPool(host='news.uic.edu', port=443): Max retries exceeded with url: /uicnews/section/circleinterchange (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://news.uic.edu/communicating-on-campus/photo-video-policies
# Error occured:  HTTPSConnectionPool(host='news.uic.edu', port=443): Max retries exceeded with url: /communicating-on-campus/photo-video-policies (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://https://today.uic.edu/coronavirus
# Error occured:  HTTPConnectionPool(host='https', port=80): Max retries exceeded with url: //today.uic.edu/coronavirus (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f5aa45d6c50>: Failed to establish a new connection: [Errno -2] Name or service not known'))
#
# Unable to connect to  https://web-travel-prod.cc.uic.edu/index.html
# Error occured:  HTTPSConnectionPool(host='web-travel-prod.cc.uic.edu', port=443): Max retries exceeded with url: /index.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ec.uic.edu/state-authorization
# Error occured:  HTTPSConnectionPool(host='ec.uic.edu', port=443): Max retries exceeded with url: /state-authorization (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://docs.financialaid.uic.edu/index.html
# Error occured:  HTTPSConnectionPool(host='docs.financialaid.uic.edu', port=443): Max retries exceeded with url: /index.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://news.uic.edu/uicnews
# Error occured:  HTTPSConnectionPool(host='news.uic.edu', port=443): Max retries exceeded with url: /uicnews (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://makerspace.uic.edu
# Error occured:  HTTPSConnectionPool(host='makerspace.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://acer.uic.edu
# Error occured:  HTTPSConnectionPool(host='acer.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://help.uic.edu
# Error occured:  HTTPSConnectionPool(host='help.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://embs.students.uic.edu
# Error occured:  HTTPSConnectionPool(host='embs.students.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://logica.students.uic.edu
# Error occured:  HTTPSConnectionPool(host='logica.students.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://advis-lab.red.uic.edu
# Error occured:  HTTPSConnectionPool(host='advis-lab.red.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://wics.students.uic.edu
# Error occured:  HTTPSConnectionPool(host='wics.students.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://theory.cs.uic.edu
# Error occured:  HTTPSConnectionPool(host='theory.cs.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://hci.cs.uic.edu
# Error occured:  HTTPSConnectionPool(host='hci.cs.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://cs.red.uic.edu/profiles/bing-liu
# Error occured:  HTTPSConnectionPool(host='cs.red.uic.edu', port=443): Max retries exceeded with url: /profiles/bing-liu (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://sisl.lab.uic.edu
# Error occured:  HTTPSConnectionPool(host='sisl.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://cs.red.uic.edu
# Error occured:  HTTPSConnectionPool(host='cs.red.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://aes.uic.edu/aes-staff
# Error occured:  HTTPSConnectionPool(host='aes.uic.edu', port=443): Max retries exceeded with url: /aes-staff (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://webmail.uic.edu
# Error occured:  HTTPSConnectionPool(host='webmail.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ec.uic.edu/assistive-technology-certificate-program
# Error occured:  HTTPSConnectionPool(host='ec.uic.edu', port=443): Max retries exceeded with url: /assistive-technology-certificate-program (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://www.psych.uic.edu
# Error occured:  HTTPSConnectionPool(host='www.psych.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://www.psych.uic.edu/research/center-on-mental-health-services-research-and-policy/about-us/about-the-center
# Error occured:  HTTPSConnectionPool(host='www.psych.uic.edu', port=443): Max retries exceeded with url: /research/center-on-mental-health-services-research-and-policy/about-us/about-the-center (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://www.psych.uic.edu/research/center-on-mental-health-services-research-and-policy/our-team
# Error occured:  HTTPSConnectionPool(host='www.psych.uic.edu', port=443): Max retries exceeded with url: /research/center-on-mental-health-services-research-and-policy/our-team (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://archive.news.uic.edu
# Error occured:  HTTPSConnectionPool(host='archive.news.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://red.uic.edu/resources/uic-web-strategy-standards
# Error occured:  HTTPSConnectionPool(host='red.uic.edu', port=443): Max retries exceeded with url: /resources/uic-web-strategy-standards (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://red.uic.edu/resources/uic-web-content-style-guide
# Error occured:  HTTPSConnectionPool(host='red.uic.edu', port=443): Max retries exceeded with url: /resources/uic-web-content-style-guide (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://emergency.uic.edu/uic-alerts
# Error occured:  HTTPSConnectionPool(host='emergency.uic.edu', port=443): Max retries exceeded with url: /uic-alerts (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://logos.uic.edu/index.cgi
# Error occured:  HTTPSConnectionPool(host='logos.uic.edu', port=443): Max retries exceeded with url: /index.cgi (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://security.uic.edu/policies
# Error occured:  HTTPSConnectionPool(host='security.uic.edu', port=443): Max retries exceeded with url: /policies (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://www.hr.uic.edu/policies
# Error occured:  HTTPSConnectionPool(host='www.hr.uic.edu', port=443): Max retries exceeded with url: /policies (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://news.uic.edu/communicating-on-campus
# Error occured:  HTTPSConnectionPool(host='news.uic.edu', port=443): Max retries exceeded with url: /communicating-on-campus (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ec.uic.edu/projectmanagement
# Error occured:  HTTPSConnectionPool(host='ec.uic.edu', port=443): Max retries exceeded with url: /projectmanagement (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://ec.uic.edu/brian-porter
# Error occured:  HTTPSConnectionPool(host='ec.uic.edu', port=443): Max retries exceeded with url: /brian-porter (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://news.uic.edu/communicating-on-campus/contact-us
# Error occured:  HTTPSConnectionPool(host='news.uic.edu', port=443): Max retries exceeded with url: /communicating-on-campus/contact-us (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://jmls-dev.red.uic.edu/experiential-learning
# Error occured:  HTTPSConnectionPool(host='jmls-dev.red.uic.edu', port=443): Max retries exceeded with url: /experiential-learning (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ccslgbtqpa.uic.edu/files/2016/06/Attendance-At-Approved-Events-Policy.pdf
# Error occured:  HTTPSConnectionPool(host='ccslgbtqpa.uic.edu', port=443): Max retries exceeded with url: /files/2016/06/Attendance-At-Approved-Events-Policy.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://go.uic.edu/pickup_upass
# Error occured:  HTTPSConnectionPool(host='cas.uic.edu', port=443): Max retries exceeded with url: /upass_pickup/index2.php (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://coeinmch.uic.edu/masks-for-moms
# Error occured:  HTTPSConnectionPool(host='coeinmch.uic.edu', port=443): Max retries exceeded with url: /masks-for-moms (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://pharmacy.uic.edu/covid19
# Error occured:  HTTPSConnectionPool(host='pharmacy.uic.edu', port=443): Max retries exceeded with url: /covid19 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://uictechcenter.uic.edu
# Error occured:  HTTPSConnectionPool(host='techcenter.uic.edu%20', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5aa47012d0>: Failed to establish a new connection: [Errno -2] Name or service not known'))
#
# Unable to connect to  https://cas.uic.edu/hhall
# Error occured:  HTTPSConnectionPool(host='cas.uic.edu', port=443): Max retries exceeded with url: /hhall (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://tigger.uic.edu/depts/oar/undergrad/transfer_requirements_undergrad.html
# Error occured:  ('Connection aborted.', OSError(0, 'Error'))
#
# Unable to connect to  http://dos.red.uic.edu/student-veterans-affairs/contact-student-veteran-affairs
# Error occured:  HTTPSConnectionPool(host='dos.red.uic.edu', port=443): Max retries exceeded with url: /student-veterans-affairs/contact-student-veteran-affairs (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://cas.uic.edu/hr/careersinstudentaffairs.shtml
# Error occured:  HTTPSConnectionPool(host='cas.uic.edu', port=443): Max retries exceeded with url: /hr/careersinstudentaffairs.shtml (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://commuter.uic.edu
# Error occured:  HTTPSConnectionPool(host='commuter.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://vpua.uic.edu/nikos-varelas-vice-provost-for-undergraduate-affairs
# Error occured:  HTTPSConnectionPool(host='vpua.uic.edu', port=443): Max retries exceeded with url: /nikos-varelas-vice-provost-for-undergraduate-affairs (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1091)')))
#
# Unable to connect to  http://ec.uic.edu
# Error occured:  HTTPSConnectionPool(host='ec.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://www.hr.uic.edu
# Error occured:  HTTPSConnectionPool(host='www.hr.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://exchange.uic.edu/owa/auth/logon.aspx?replaceCurrent=1&url=https%3a%2f%2fexchange.uic.edu%2fowa%2f
# Error occured:  HTTPSConnectionPool(host='exchange.uic.edu', port=443): Max retries exceeded with url: /owa/auth/logon.aspx?replaceCurrent=1&url=https%3a%2f%2fexchange.uic.edu%2fowa%2f (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://parkingservices.uic.edu
# Error occured:  HTTPSConnectionPool(host='parkingservices.uic.edu', port=443): Max retries exceeded with url: /Home (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://fm.red.uic.edu
# Error occured:  HTTPSConnectionPool(host='fm.red.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://ovcas.red.uic.edu
# Error occured:  HTTPSConnectionPool(host='ovcas.red.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://logos.uic.edu/index.cgi
# Error occured:  HTTPSConnectionPool(host='logos.uic.edu', port=443): Max retries exceeded with url: /index.cgi (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://red.uic.edu
# Error occured:  HTTPSConnectionPool(host='red.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://fmweb.fm.uic.edu
# Error occured:  HTTPConnectionPool(host='fmweb.fm.uic.edu', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f5aa45ea250>: Failed to establish a new connection: [Errno -2] Name or service not known'))
#
# Unable to connect to  https://clery.uic.edu
# Error occured:  HTTPSConnectionPool(host='clery.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://studyabroad.red.uic.edu/advising
# Error occured:  HTTPSConnectionPool(host='studyabroad.red.uic.edu', port=443): Max retries exceeded with url: /advising (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://oia.uic.edu/about/oia-programs/international-agreements/active-uic-international-agreements
# Error occured:  HTTPSConnectionPool(host='oia.uic.edu', port=443): Max retries exceeded with url: /about/oia-programs/international-agreements/active-uic-international-agreements (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5aa5829d90>: Failed to establish a new connection: [Errno 110] Connection timed out'))
#
# Unable to connect to  https://oia.uic.edu/files/2014/06/IDF-AY20-21_APPLICATION-FORM-1-1.pdf
# Error occured:  HTTPSConnectionPool(host='oia.uic.edu', port=443): Max retries exceeded with url: /files/2014/06/IDF-AY20-21_APPLICATION-FORM-1-1.pdf (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5aa09bb650>: Failed to establish a new connection: [Errno 110] Connection timed out'))
#
# Unable to connect to  https://oia.uic.edu/files/2020/09/CCC-AWARDS-AY20-21APPLICATION-FORM.pdf
# Error occured:  HTTPSConnectionPool(host='oia.uic.edu', port=443): Max retries exceeded with url: /files/2020/09/CCC-AWARDS-AY20-21APPLICATION-FORM.pdf (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5aa09ab850>: Failed to establish a new connection: [Errno 110] Connection timed out'))
#
# Unable to connect to  https://oia.uic.edu/files/2020/09/DRUMRIGHT-AWARDS-AY20_21-APPLICATION-FORM.pdf
# Error occured:  HTTPSConnectionPool(host='oia.uic.edu', port=443): Max retries exceeded with url: /files/2020/09/DRUMRIGHT-AWARDS-AY20_21-APPLICATION-FORM.pdf (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5aa09a0190>: Failed to establish a new connection: [Errno 110] Connection timed out'))
#
# Unable to connect to  https://oia.uic.edu/files/2020/09/JNC-STUDENTS-AY20-21_APPLICATION-FORM.pdf
# Error occured:  HTTPSConnectionPool(host='oia.uic.edu', port=443): Max retries exceeded with url: /files/2020/09/JNC-STUDENTS-AY20-21_APPLICATION-FORM.pdf (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5aa09a0ad0>: Failed to establish a new connection: [Errno 110] Connection timed out'))
#
# Unable to connect to  https://listserv.uic.edu/cgi-bin/wa
# Error occured:  HTTPSConnectionPool(host='listserv.uic.edu', port=443): Max retries exceeded with url: /cgi-bin/wa (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ask.publish.uic.edu
# Error occured:  HTTPSConnectionPool(host='ask.publish.uic.edu', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5aa4025d10>: Failed to establish a new connection: [Errno 110] Connection timed out'))
#
# Unable to connect to  https://grad.red.uic.edu/programs/certificate-in-the-foundations-of-college-instruction
# Error occured:  HTTPSConnectionPool(host='grad.red.uic.edu', port=443): Max retries exceeded with url: /programs/certificate-in-the-foundations-of-college-instruction (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ec.uic.edu
# Error occured:  HTTPSConnectionPool(host='ec.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ce.pharmacy.uic.edu
# Error occured:  HTTPSConnectionPool(host='ce.pharmacy.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://www.psych.uic.edu/education/continuing-education
# Error occured:  HTTPSConnectionPool(host='www.psych.uic.edu', port=443): Max retries exceeded with url: /education/continuing-education (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://coeinmch.uic.edu/professional-development/continuing-education-programming
# Error occured:  HTTPSConnectionPool(host='coeinmch.uic.edu', port=443): Max retries exceeded with url: /professional-development/continuing-education-programming (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://www.psych.uic.edu/education/continuing-education/social-work-continuing-education
# Error occured:  HTTPSConnectionPool(host='www.psych.uic.edu', port=443): Max retries exceeded with url: /education/continuing-education/social-work-continuing-education (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://eyecare.uic.edu
# Error occured:  HTTPSConnectionPool(host='eyecare.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://asme.students.uic.edu
# Error occured:  HTTPSConnectionPool(host='asme.students.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://bmes.students.uic.edu
# Error occured:  HTTPSConnectionPool(host='bmes.students.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ewh.students.uic.edu
# Error occured:  HTTPSConnectionPool(host='ewh.students.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://esw.students.uic.edu
# Error occured:  HTTPSConnectionPool(host='esw.students.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ieee.students.uic.edu
# Error occured:  HTTPSConnectionPool(host='ieee.students.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://iise.students.uic.edu
# Error occured:  HTTPSConnectionPool(host='iise.students.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ostem.students.uic.edu
# Error occured:  HTTPSConnectionPool(host='ostem.students.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://sae.uic.edu
# Error occured:  HTTPSConnectionPool(host='sae.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://sase.students.uic.edu
# Error occured:  HTTPSConnectionPool(host='sase.students.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://swe.students.uic.edu
# Error occured:  HTTPSConnectionPool(host='swe.students.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://vese.students.uic.edu
# Error occured:  HTTPSConnectionPool(host='vese.students.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://etakappanu.students.uic.edu
# Error occured:  HTTPSConnectionPool(host='etakappanu.students.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://pts.students.uic.edu
# Error occured:  HTTPSConnectionPool(host='pts.students.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://tbp.students.uic.edu
# Error occured:  HTTPSConnectionPool(host='tbp.students.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://web.bioe.uic.edu/bioe-wp/bioe-undergrad/conc_area_form_fa16present.pdf
# Error occured:  HTTPSConnectionPool(host='web.bioe.uic.edu', port=443): Max retries exceeded with url: /bioe-wp/bioe-undergrad/conc_area_form_fa16present.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://web.bioe.uic.edu/bioe-wp/bioe-undergrad/conc_area_form_fa14sp16.pdf
# Error occured:  HTTPSConnectionPool(host='web.bioe.uic.edu', port=443): Max retries exceeded with url: /bioe-wp/bioe-undergrad/conc_area_form_fa14sp16.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://web.bioe.uic.edu/bioe-wp/bioe-undergrad/conc_area_form_fa12sp14.pdf
# Error occured:  HTTPSConnectionPool(host='web.bioe.uic.edu', port=443): Max retries exceeded with url: /bioe-wp/bioe-undergrad/conc_area_form_fa12sp14.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://web.bioe.uic.edu/bioe-wp/bioe-undergrad/curr_flow_fa16present.htm
# Error occured:  HTTPSConnectionPool(host='web.bioe.uic.edu', port=443): Max retries exceeded with url: /bioe-wp/bioe-undergrad/curr_flow_fa16present.htm (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://web.bioe.uic.edu/bioe-wp/bioe-undergrad/curr_flow_fa14sp16.htm
# Error occured:  HTTPSConnectionPool(host='web.bioe.uic.edu', port=443): Max retries exceeded with url: /bioe-wp/bioe-undergrad/curr_flow_fa14sp16.htm (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://web.bioe.uic.edu/bioe-wp/bioe-undergrad/curr_flow_fa12sp14.htm
# Error occured:  HTTPSConnectionPool(host='web.bioe.uic.edu', port=443): Max retries exceeded with url: /bioe-wp/bioe-undergrad/curr_flow_fa12sp14.htm (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://docs.financialaid.uic.edu/docs/PDF_upload_guide.pdf
# Error occured:  HTTPSConnectionPool(host='docs.financialaid.uic.edu', port=443): Max retries exceeded with url: /docs/PDF_upload_guide.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://docs.financialaid.uic.edu/docs/QUICK INFORMATION_UNDERGRADUATES.pdf
# Error occured:  HTTPSConnectionPool(host='docs.financialaid.uic.edu', port=443): Max retries exceeded with url: /docs/QUICK%20INFORMATION_UNDERGRADUATES.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://docs.financialaid.uic.edu/docs/SAP_Appeal_Evaluation_Form.pdf
# Error occured:  HTTPSConnectionPool(host='docs.financialaid.uic.edu', port=443): Max retries exceeded with url: /docs/SAP_Appeal_Evaluation_Form.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://docs.financialaid.uic.edu/docs/2019FACalendar.pdf
# Error occured:  HTTPSConnectionPool(host='docs.financialaid.uic.edu', port=443): Max retries exceeded with url: /docs/2019FACalendar.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://docs.financialaid.uic.edu/docs/2018FACalendar.pdf
# Error occured:  HTTPSConnectionPool(host='docs.financialaid.uic.edu', port=443): Max retries exceeded with url: /docs/2018FACalendar.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ure.uic.edu/facfws.php
# Error occured:  HTTPSConnectionPool(host='ure.uic.edu', port=443): Max retries exceeded with url: /facfws.php (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://pharmacy.uic.edu/about/rockford-campus
# Error occured:  HTTPSConnectionPool(host='pharmacy.uic.edu', port=443): Max retries exceeded with url: /about/rockford-campus (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://anand.lab.uic.edu
# Error occured:  HTTPSConnectionPool(host='anand.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://shahbazian.lab.uic.edu
# Error occured:  HTTPSConnectionPool(host='shahbazian.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://csun.uic.edu
# Error occured:  HTTPSConnectionPool(host='csun.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://gagel.lab.uic.edu
# Error occured:  HTTPSConnectionPool(host='gagel.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://mazumder.lab.uic.edu
# Error occured:  HTTPSConnectionPool(host='mazumder.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://nde.lab.uic.edu
# Error occured:  HTTPSConnectionPool(host='nde.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://jameslee.lab.uic.edu
# Error occured:  HTTPSConnectionPool(host='jameslee.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://aeon.lab.uic.edu
# Error occured:  HTTPSConnectionPool(host='aeon.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://mmnl.lab.uic.edu
# Error occured:  HTTPSConnectionPool(host='mmnl.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://nrl.ece.uic.edu/people.html
# Error occured:  HTTPSConnectionPool(host='nrl.ece.uic.edu', port=443): Max retries exceeded with url: /people.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://isnl.lab.uic.edu/isnl-dr.-tolou-shokuhfar.html
# Error occured:  HTTPSConnectionPool(host='isnl.lab.uic.edu', port=443): Max retries exceeded with url: /isnl-dr.-tolou-shokuhfar.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://bestbioe.lab.uic.edu
# Error occured:  HTTPSConnectionPool(host='bestbioe.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://esmailbeigi.lab.uic.edu
# Error occured:  HTTPSConnectionPool(host='esmailbeigi.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://aes.uic.edu/programs/presidents-award-program.html
# Error occured:  HTTPSConnectionPool(host='aes.uic.edu', port=443): Max retries exceeded with url: /programs/presidents-award-program.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://papautsky.lab.uic.edu
# Error occured:  HTTPSConnectionPool(host='papautsky.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://amml.lab.uic.edu
# Error occured:  HTTPSConnectionPool(host='amml.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://cbrl.lab.uic.edu
# Error occured:  HTTPSConnectionPool(host='cbrl.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://themirbod.lab.uic.edu
# Error occured:  HTTPSConnectionPool(host='themirbod.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://yayuepan.lab.uic.edu
# Error occured:  HTTPSConnectionPool(host='yayuepan.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://nicest.lab.uic.edu
# Error occured:  HTTPSConnectionPool(host='nicest.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://acoustics.mie.uic.edu
# Error occured:  HTTPSConnectionPool(host='acoustics.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://meml.lab.uic.edu
# Error occured:  HTTPSConnectionPool(host='meml.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://translog.uic.edu
# Error occured:  HTTPSConnectionPool(host='translog.lab.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://nicest.lab.uic.edu/profiles/smida-besma
# ...
#
# Unable to connect to  https://cas.uic.edu/upass_pickup/index2.php
# Error occured:  HTTPSConnectionPool(host='cas.uic.edu', port=443): Max retries exceeded with url: /upass_pickup/index2.php (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://go.uic.edu/spring_upass
# Error occured:  Exceeded 30 redirects.
#
# Unable to connect to  https://convocation.uic.edu
# Error occured:  HTTPSConnectionPool(host='convocation.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://wow.uic.edu
# Error occured:  HTTPSConnectionPool(host='studentaffairs.uic.edu', port=443): Max retries exceeded with url: /wow (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://cas.uic.edu/wordpresspreview/scw/scw.html
# Error occured:  HTTPSConnectionPool(host='cas.uic.edu', port=443): Max retries exceeded with url: /wordpresspreview/scw/scw.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://cas.uic.edu/wordpresspreview/sce/sce.html
# Error occured:  HTTPSConnectionPool(host='cas.uic.edu', port=443): Max retries exceeded with url: /wordpresspreview/sce/sce.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://studentcenters.red.uic.edu/wp-content/uploads/sites/159/2017/11/Green-Office-Guide.pdf
# Error occured:  HTTPSConnectionPool(host='studentcenters.red.uic.edu', port=443): Max retries exceeded with url: /wp-content/uploads/sites/159/2017/11/Green-Office-Guide.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://vcsa.uic.edu
# Error occured:  HTTPSConnectionPool(host='vcsa.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1091)')))
#
# Unable to connect to  https://commuter.uic.edu/housing
# Error occured:  HTTPSConnectionPool(host='commuter.uic.edu', port=443): Max retries exceeded with url: /housing (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://satestb.red.uic.edu/wp-content/uploads/sites/10/2017/11/AOD_UPDATED_9517.pdf
# Error occured:  HTTPSConnectionPool(host='satestb.red.uic.edu', port=443): Max retries exceeded with url: /wp-content/uploads/sites/10/2017/11/AOD_UPDATED_9517.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://satestb.red.uic.edu/wp-content/uploads/sites/10/2017/11/Campus-Violence-Response-and-Prevention-PlanUniversity-of-Illinoi.pdf
# Error occured:  HTTPSConnectionPool(host='satestb.red.uic.edu', port=443): Max retries exceeded with url: /wp-content/uploads/sites/10/2017/11/Campus-Violence-Response-and-Prevention-PlanUniversity-of-Illinoi.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://www.uic.edu/pharmacy
# Error occured:  HTTPSConnectionPool(host='pharmacy.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://news.uic.edu/staff/sherri-mcginnis-gonzalez/120213_mcginnis_gonzalez_030
# Error occured:  HTTPSConnectionPool(host='news.uic.edu', port=443): Max retries exceeded with url: /staff/sherri-mcginnis-gonzalez/120213_mcginnis_gonzalez_030 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://news.uic.edu/staff/jeffron-boynes/120213_boynes_015
# Error occured:  HTTPSConnectionPool(host='news.uic.edu', port=443): Max retries exceeded with url: /staff/jeffron-boynes/120213_boynes_015 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://news.uic.edu/staff/brian-flood/120213_flood_027
# Error occured:  HTTPSConnectionPool(host='news.uic.edu', port=443): Max retries exceeded with url: /staff/brian-flood/120213_flood_027 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://news.uic.edu/staff/christy-levy/120213_levy_026
# Error occured:  HTTPSConnectionPool(host='news.uic.edu', port=443): Max retries exceeded with url: /staff/christy-levy/120213_levy_026 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ec.uic.edu/courses
# Error occured:  HTTPSConnectionPool(host='ec.uic.edu', port=443): Max retries exceeded with url: /courses (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ec.uic.edu/programs
# Error occured:  HTTPSConnectionPool(host='ec.uic.edu', port=443): Max retries exceeded with url: /programs (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ec.uic.edu/cnm
# Error occured:  HTTPSConnectionPool(host='ec.uic.edu', port=443): Max retries exceeded with url: /cnm (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ec.uic.edu/grant-writing-workshop
# Error occured:  HTTPSConnectionPool(host='ec.uic.edu', port=443): Max retries exceeded with url: /grant-writing-workshop (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ec.uic.edu/social-enterprise-certificate
# Error occured:  HTTPSConnectionPool(host='ec.uic.edu', port=443): Max retries exceeded with url: /social-enterprise-certificate (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ec.uic.edu/partner-with-us
# Error occured:  HTTPSConnectionPool(host='ec.uic.edu', port=443): Max retries exceeded with url: /partner-with-us (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ec.uic.edu/request-information
# Error occured:  HTTPSConnectionPool(host='ec.uic.edu', port=443): Max retries exceeded with url: /request-information (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ec.uic.edu/about
# Error occured:  HTTPSConnectionPool(host='ec.uic.edu', port=443): Max retries exceeded with url: /about (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ec.uic.edu/cnm/courses/donor-relationships
# Error occured:  HTTPSConnectionPool(host='ec.uic.edu', port=443): Max retries exceeded with url: /cnm/courses/donor-relationships (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ec.uic.edu/cnm/courses/nonprofits-today
# Error occured:  HTTPSConnectionPool(host='ec.uic.edu', port=443): Max retries exceeded with url: /cnm/courses/nonprofits-today (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ec.uic.edu/cnm/courses
# Error occured:  HTTPSConnectionPool(host='ec.uic.edu', port=443): Max retries exceeded with url: /cnm/courses (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ec.uic.edu/grant-writing-workshop/noah-temaner-jenkins
# Error occured:  HTTPSConnectionPool(host='ec.uic.edu', port=443): Max retries exceeded with url: /grant-writing-workshop/noah-temaner-jenkins (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://ec.uic.edu/grant-writing-workshop/valerie-leonard
# Error occured:  HTTPSConnectionPool(host='ec.uic.edu', port=443): Max retries exceeded with url: /grant-writing-workshop/valerie-leonard (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://news.uic.edu/files/2014/11/IMG_8600.jpg
# Error occured:  HTTPSConnectionPool(host='news.uic.edu', port=443): Max retries exceeded with url: /files/2014/11/IMG_8600.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://news.uic.edu/experts/zizi-papacharissi/zizi-papacharissi-2
# Error occured:  HTTPSConnectionPool(host='news.uic.edu', port=443): Max retries exceeded with url: /experts/zizi-papacharissi/zizi-papacharissi-2 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://https://comm.uic.edu/profiles/zizi-papacharissi
# Error occured:  HTTPConnectionPool(host='https', port=80): Max retries exceeded with url: //comm.uic.edu/profiles/zizi-papacharissi (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f5a9e2e1d10>: Failed to establish a new connection: [Errno -2] Name or service not known'))
#
# Unable to connect to  http://news.uic.edu/files/2016/02/Weine.Stevan27.jpg
# Error occured:  HTTPSConnectionPool(host='news.uic.edu', port=443): Max retries exceeded with url: /files/2016/02/Weine.Stevan27.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  http://www.psych.uic.edu/154-about-us/directory/faculty/266-steve-weine
# Error occured:  HTTPSConnectionPool(host='www.psych.uic.edu', port=443): Max retries exceeded with url: /154-about-us/directory/faculty/266-steve-weine (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://findingaids.library.uic.edu/sc/msscic94.xml
# Error occured:  HTTPSConnectionPool(host='findingaids.library.uic.edu', port=443): Max retries exceeded with url: /sc/msscic94.xml (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://www.hr.uic.edu/classification_and_compensation/about_civil_service
# Error occured:  HTTPSConnectionPool(host='www.hr.uic.edu', port=443): Max retries exceeded with url: /classification_and_compensation/about_civil_service (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://www.hr.uic.edu/managing_my_performance/annual_performance_review
# Error occured:  HTTPSConnectionPool(host='www.hr.uic.edu', port=443): Max retries exceeded with url: /managing_my_performance/annual_performance_review (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://groups.accc.uic.edu
# Error occured:  HTTPSConnectionPool(host='groups.accc.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://campusprograms.uic.edu
# Error occured:  HTTPSConnectionPool(host='campusprograms.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1091)')))
#
# Unable to connect to  http://news.uic.edu/files/2015/10/DG15_04_50_005.jpg
# Error occured:  HTTPSConnectionPool(host='news.uic.edu', port=443): Max retries exceeded with url: /files/2015/10/DG15_04_50_005.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))
#
# Unable to connect to  https://courseval.den.uic.edu/etw/ets/et.asp
# Error occured:  HTTPSConnectionPool(host='courseval.den.uic.edu', port=443): Max retries exceeded with url: /etw/ets/et.asp (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5aa4017cd0>: Failed to establish a new connection: [Errno 110] Connection timed out'))
#
# Unable to connect to  http://portal.den.uic.edu
# Error occured:  HTTPConnectionPool(host='portal.den.uic.edu', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f5aa298f490>: Failed to establish a new connection: [Errno 110] Connection timed out'))
#
# Unable to connect to  https://portal.den.uic.edu
# Error occured:  HTTPSConnectionPool(host='portal.den.uic.edu', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f5aa29bfb90>: Failed to establish a new connection: [Errno 110] Connection timed out'))
#
# Unable to connect to  http://bsn.ec.uic.edu
# Error occured:  HTTPSConnectionPool(host='bsn.ec.uic.edu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')))

# %%
pickle_folder = "./Pickle_Folder/"
os.makedirs(pickle_folder, exist_ok=True)

# Pickling the dict of crawled pages
with open(pickle_folder + '6000_url_pages.pickle', 'wb') as f:
    pickle.dump(crawled_pages,f)


with open(pickle_folder + '6000_url_pages.pickle', 'rb') as f:
    url_pages = pickle.load(f)

crawled_pages == url_pages
# Out:
# True

# %%
len(crawled_pages)
# Out:
# 6001
